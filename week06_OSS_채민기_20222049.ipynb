# %%
#1
def factorial (n):
  """return n!"""
  return 1 if n<2 else n* factorial(n-1)

# %%
factorial(42)
# Out:
# 1405006117752879898543142606244511569936384000000000

# %%
factorial.__doc__
# Out:
# 'return n!'

# %%
type(factorial)
# Out:
# function

# %%
#2
help(factorial)
# Out:
# Help on function factorial in module __main__:
#
# factorial(n)
#     return n!

# %%
#3
fact=factorial
fact
# Out:
# <function __main__.factorial(n)>

# %%
fact(5)
# Out:
# 120

# %%
map(factorial, range(11))

# %%
list(map(fact,range(11)))
# Out:
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]

# %%
#4
fruits=['strawbarry','fig','apple','cherry','raspberry','banana']
sorted(fruits,key=len)
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspberry', 'strawbarry']

# %%
#5
def reverse(word):
  return word[::-1]
reverse('testing')
# Out:
# 'gnitset'

# %%
sorted(fruits,key=reverse)
# Out:
# ['banana', 'apple', 'fig', 'strawbarry', 'raspberry', 'cherry']

# %%
#6
list(map(fact, range(6)))
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
[fact(n) for n in range(6)]
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
list(map(factorial,filter(lambda n: n%2, range(6))))
# Out:
# [1, 6, 120]

# %%
[factorial(n) for n in range(6) if n%2]
# Out:
# [1, 6, 120]

# %%
#7
fruits=['strawbarry','fig','apple','cherry','raspberry','banana']

sorted(fruits, key =lambda word: word[::-1])
# Out:
# ['banana', 'apple', 'fig', 'strawbarry', 'raspberry', 'cherry']

# %%
#8
abs, str,13
# Out:
# (<function abs(x, /)>, str, 13)

# %%
[callable(obj) for obj in (abs,str,13)]
# Out:
# [True, True, False]

# %%
#9
import random

class BingoCage:
  def __init__(self, items):
    self._items=list(items)
    random.shuffle(self._items)
  def pick(self):
    try:
      return self._items.pop()
    except:
      raise LookupError('pick from empty BigoCage')
  def __call__(self):
    return self.pick()

# %%
#10
bingo= BingoCage(range(3))
bingo.pick()
# Out:
# 0

# %%
bingo()
# Out:
# 1

# %%
callable(bingo)
# Out:
# True

# %%
bingo()
# Out:
# 2

# %%
#11
bingo()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-804799612.py in pick(self)
#       9     try:
# ---> 10       return self._items.pop()
#      11     except:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-3122722561.py in <cell line: 0>()
#       1 #11
# ----> 2 bingo()
#
# /tmp/ipython-input-804799612.py in __call__(self)
#      12       raise LookupError('pick from empty BigoCage')
#      13   def __call__(self):
# ---> 14     return self.pick()
#
# /tmp/ipython-input-804799612.py in pick(self)
#      10       return self._items.pop()
#      11     except:
# ---> 12       raise LookupError('pick from empty BigoCage')
#      13   def __call__(self):
#      14     return self.pick()
#
# LookupError: pick from empty BigoCage

# %%
def tag(name, *content, cls=None, **attrs):
    """하나 이상의 HTML 태그를 생성"""
    if cls is not None:
        attrs['class'] = cls

    # 속성 문자열 만들기 (수정된 부분)
    if attrs:
        attr_str = ''.join(' %s="%s"' % (attr, value)
                           for attr, value in sorted(attrs.items()))
    else:
        attr_str = ''

    # 내용이 있을 때와 없을 때 구분
    if content:
        return '\n'.join('<%s%s>%s</%s>' % (name, attr_str, c, name) for c in content)
    else:
        return '<%s%s />' % (name, attr_str)

# %%
#13
tag('br')
# Out:
# '<br />'

# %%
tag('p', 'hello')
# Out:
# '<p>hello</p>'

# %%
print(tag('p','hello','word'))
# Out:
# <p>hello</p>
# <p>word</p>

# %%
tag('p','hello',id=33)
# Out:
# '<p id="33">hello</p>'

# %%
tag(content='testing',name='img')
# Out:
# '<img content="testing" />'

# %%
my_tag={'name':'img','title':'Sunest Boulevard','src':'sunset.jpg','cls':'framed'}
tag(**my_tag)
# Out:
# '<img class="framed" src="sunset.jpg" title="Sunest Boulevard" />'

# %%
#15
def f(a,*,b):
  return a,b
f(1, b=2)
# Out:
# (1, 2)

# %%
#16
def create_user(name,*,age, is_admin=False):
  print(f"name:{name},Age:{age},Admin:{is_admin}")
create_user("Alice",age=30, is_admin=True)
create_user("Bob",25)
# Out:
# name:Alice,Age:30,Admin:True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1374910155.py in <cell line: 0>()
#       3   print(f"name:{name},Age:{age},Admin:{is_admin}")
#       4 create_user("Alice",age=30, is_admin=True)
# ----> 5 create_user("Bob",25)
#
# TypeError: create_user() takes 1 positional argument but 2 were given

# %%
#17
def clip(text, max_len=80):
  """max_len 앞이나 뒤의 마지막 공백에서 잘라낸 텍스트를 반환한다."""
  end=None
  if len(text)>max_len:
    space_before=text.rfind('',0,max_len)

    if space_before>=0:
      end= space_before
    else:
      space_after=text.rfind('',max_len)

      if space_after>=0:
        end= space_after
  if end is None:
    end=len(text)
  return text[:end].rstrip()

# %%
#18
clip.__defaults__
# Out:
# (80,)

# %%
clip.__code__
# Out:
# <code object clip at 0x7f2084066100, file "/tmp/ipython-input-1796465923.py", line 2>

# %%
clip.__code__.co_varnames
# Out:
# ('text', 'max_len', 'end', 'space_before', 'space_after')

# %%
clip.__code__.co_argcount
# Out:
# 2

# %%
#19
from inspect import signature
sig=signature(clip)
sig
# Out:
# <Signature (text, max_len=80)>

# %%
str(sig)
# Out:
# '(text, max_len=80)'

# %%
for name, param in sig.parameters.items():
  print(param.kind,":", name, "=",param.default)
# Out:
# POSITIONAL_OR_KEYWORD : text = <class 'inspect._empty'>
# POSITIONAL_OR_KEYWORD : max_len = 80

# %%
#20
from inspect import signature

sig=signature(tag)
my_tag
# Out:
# {'name': 'img',
#  'title': 'Sunest Boulevard',
#  'src': 'sunset.jpg',
#  'cls': 'framed'}

# %%
bound_args=sig.bind(**my_tag)
bound_args
# Out:
# <BoundArguments (name='img', cls='framed', attrs={'title': 'Sunest Boulevard', 'src': 'sunset.jpg'})>

# %%
for name,value in bound_args.arguments.items():
  print(name,'=',value)
# Out:
# name = img
# cls = framed
# attrs = {'title': 'Sunest Boulevard', 'src': 'sunset.jpg'}

# %%
del my_tag['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3024270569.py in <cell line: 0>()
# ----> 1 del my_tag['name']
#
# KeyError: 'name'

# %%
bound_args=sig.bind(**my_tag)
bound_args
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4011044321.py in <cell line: 0>()
# ----> 1 bound_args=sig.bind(**my_tag)
#       2 bound_args
#
# /usr/lib/python3.12/inspect.py in bind(self, *args, **kwargs)
#    3278         if the passed arguments can not be bound.
#    3279         """
# -> 3280         return self._bind(args, kwargs)
#    3281
#    3282     def bind_partial(self, /, *args, **kwargs):
#
# /usr/lib/python3.12/inspect.py in _bind(self, args, kwargs, partial)
#    3191                             msg = 'missing a required{argtype} argument: {arg!r}'
#    3192                             msg = msg.format(arg=param.name, argtype=argtype)
# -> 3193                             raise TypeError(msg) from None
#    3194             else:
#    3195                 # We have a positional argument to process
#
# TypeError: missing a required argument: 'name'

# %%
#21
def clip_fa(text:str,max_len:'int>0'=80)-> str:
  """max_len앞이나 뒤의 마지막 공백에서 잘라낸 텍스트를 반환한다."""

  end=None
  if len(text)>max_len:
    space_before=text.rfind('',0,max_len)

    if space_before>=0:
      end= space_before
    else:
      space_after=text.rfind('',max_len)

      if space_after>=0:
        end= space_after
  if end is None:
    end=len(text)
  return text[:end].rstrip()

# %%
#22
clip_fa.__annotations__
# Out:
# {'text': str, 'max_len': 'int>0', 'return': str}

# %%
#23
clip_fa.__annotations__
# Out:
# {'text': str, 'max_len': 'int>0', 'return': str}

# %%
sig2=signature(clip_fa)
sig2.return_annotation
# Out:
# str

# %%
for param in sig2.parameters.values():
  note=repr(param.annotation).ljust(13)
  print(note,':',param.name,'=',param.default)
# Out:
# <class 'str'> : text = <class 'inspect._empty'>
# 'int>0'       : max_len = 80

# %%
#24
from functools import reduce

def fact(n):
  return reduce(lambda a,b: a*b, range(1,n+1))
fact(10)
# Out:
# 3628800

# %%
#25
from operator import mul

def fact(n):
  return reduce(mul,range(1,n+1))
fact(10)
# Out:
# 3628800

# %%
#26

metro_data=[
    ('Tokyo','JP',36.933,(35.689722,139.691667)),
    ('Delhi NCR', 'IN',21.935,(28.613889,77.208889)),
    ('Mexico City','MX',20.142,(19.433333,-99.133333)),
    ('New York-newark','US',20.104,(40.808611,-74.020386)),
    ('Sao Paulo','BR',19.649,(-23.547778,-46.635833)),
]

# %%
from operator import itemgetter
for city in sorted(metro_data,key=itemgetter(1)):
  print(city)
# Out:
# ('Sao Paulo', 'BR', 19.649, (-23.547778, -46.635833))
# ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889))
# ('Tokyo', 'JP', 36.933, (35.689722, 139.691667))
# ('Mexico City', 'MX', 20.142, (19.433333, -99.133333))
# ('New York-newark', 'US', 20.104, (40.808611, -74.020386))

# %%
#27
cc_name=itemgetter(1,0)
for city in metro_data:
  print(cc_name(city))
# Out:
# ('JP', 'Tokyo')
# ('IN', 'Delhi NCR')
# ('MX', 'Mexico City')
# ('US', 'New York-newark')
# ('BR', 'Sao Paulo')

# %%
#28
from collections import namedtuple
LatLong=namedtuple('LatLong','lat long')
Metropolis=namedtuple('Metropolis','name cc pop coord')
metro_areas=[Metropolis(name,cc,pop,LatLong(lat,long)) for name,cc,pop,(lat,long) in metro_data]

metro_areas[0]
# Out:
# Metropolis(name='Tokyo', cc='JP', pop=36.933, coord=LatLong(lat=35.689722, long=139.691667))

# %%
metro_areas[0].coord.lat
# Out:
# 35.689722

# %%
from operator import attrgetter
name_lat= attrgetter('name', 'coord.lat')

name_lat(metro_areas[0])
# Out:
# ('Tokyo', 35.689722)

# %%
#28
for city in sorted(metro_areas,key=attrgetter('coord.lat')):
  print(name_lat(city))
# Out:
# ('Sao Paulo', -23.547778)
# ('Mexico City', 19.433333)
# ('Delhi NCR', 28.613889)
# ('Tokyo', 35.689722)
# ('New York-newark', 40.808611)

# %%
metro_areas2=[Metropolis(name,cc,pop,LatLong(*loc)) for name,cc,pop, loc in metro_data]
metro_areas2[0]
# Out:
# Metropolis(name='Tokyo', cc='JP', pop=36.933, coord=LatLong(lat=35.689722, long=139.691667))

# %%
#29
from operator import methodcaller
s='The time has come'
upcase=methodcaller('upper')

upcase(s)
# Out:
# 'THE TIME HAS COME'

# %%
s.upper()
# Out:
# 'THE TIME HAS COME'

# %%
hisphenate=methodcaller('replace',' ','-')
hisphenate(s)
# Out:
# 'The-time-has-come'

# %%
#30
from operator import mul
from functools import partial

triple= partial(mul,3)
triple(7)
# Out:
# 21

# %%
list(map(triple,range(1,10)))
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
#31
import unicodedata
nfc=partial(unicodedata.normalize,'NFC')

s1='café'
s2='cafe\u0301'
s1,s2
# Out:
# ('café', 'café')

# %%
s1==s2,nfc(s1)==nfc(s2)
# Out:
# (False, True)

# %%
#32
tag
picture = partial(tag,'img',cls='pic=frame')

picture(src='wumpus.jpg')
# Out:
# '<img class="pic=frame" src="wumpus.jpg" />'

# %%
tag,picture,picture.func, picture.args,picture.keywords
# Out:
# (<function __main__.tag(name, *content, cls=None, **attrs)>,
#  functools.partial(<function tag at 0x7f2084075da0>, 'img', cls='pic=frame'),
#  <function __main__.tag(name, *content, cls=None, **attrs)>,
#  ('img',),
#  {'cls': 'pic=frame'})
